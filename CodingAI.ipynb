# %% [markdown]
# <a href="https://colab.research.google.com/github/Ja1Pat3L/RadicalX_Challenge2/blob/main/CodingAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install streamlit --quiet
# %pip install langchain --quiet

# %%
import streamlit as st
from Pair_Program_Backend import *
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspaces/RadicalX_Challenge2/CodingAI.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell://codespaces%2Bmusical-guacamole-w4g9pxvr9g7fwrw/workspaces/RadicalX_Challenge2/CodingAI.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import streamlit as st
# ----> <a href='vscode-notebook-cell://codespaces%2Bmusical-guacamole-w4g9pxvr9g7fwrw/workspaces/RadicalX_Challenge2/CodingAI.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> from Pair_Program_Backend import *
#
# File /workspaces/RadicalX_Challenge2/Pair_Program_Backend.py:7
#       1 {
#       2   "nbformat": 4,
#       3   "nbformat_minor": 0,
#       4   "metadata": {
#       5     "colab": {
#       6       "provenance": [],
# ----> 7       "include_colab_link": true
#       8     },
#       9     "kernelspec": {
#      10       "name": "python3",
# ...
